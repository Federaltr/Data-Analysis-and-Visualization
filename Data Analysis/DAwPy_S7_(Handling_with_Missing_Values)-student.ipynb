# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src=https://i.ibb.co/6gCsHd6/1200px-Pandas-logo-svg.png width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Session - 07</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#4d77cf; font-size:200%; text-align:center; border-radius:10px 10px;">Handling with Missing Values</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK](#0)
# * [TYPE OF NAN VALUES](#1)
# * [DETECTING MISSING VALUES](#2)
# * [CONVERTING INAPPROPRIATE VALUES TO NAN VALUES](#3)
# * [MISSING VALUE HANDLING METHODS](#4)
# * [THE END OF THE SESSION - 07](#5)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Libraries Needed in This Notebook</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
id_no = ["P001", "P002", "P003", "P004", "P005", "P006", "P007", "P008", "P009", "P010", "P011"]
gender = ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F", "M"]
status = ["FT", "PT", "-", "FT", "PT", "PT", "FT", "-", "PT", "FT", np.nan]
dept = ["DS", "FS", "AWS", "AWS", "DS", None, "FS", "FS", np.nan, "DS", "AWS"]
V1 = np.array([2, 3, 5, np.nan, 7, 1, np.nan, 10, 14, "-", 6])
V2 = np.array([8, np.nan, 5, 8, 11, np.nan, np.nan, 2, 3, 7, 9])
salary = np.array([np.nan, 54, 59, 120, 58, 75, None, 136, 60, 125, np.nan])

df = pd.DataFrame({
                   "id" : id_no,
                   "gender": gender,
                   "status": status,
                   "dept": dept,
                   "var1" : V1,
                   "var2" : V2,
                   "salary" : salary
                  })
df
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Type of NaN Values</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df.info()  #string herhangi bir ifadeyi NaN oalrak görmez.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   gender  11 non-null     object
#  2   status  10 non-null     object
#  3   dept    9 non-null      object
#  4   var1    11 non-null     object
#  5   var2    8 non-null      float64
#  6   salary  8 non-null      object
# dtypes: float64(1), object(6)
# memory usage: 744.0+ bytes

# %%
type(np.nan)
# Out:
# float

# %%
type(np.NaN)
# Out:
# float

# %%
type(None)
# Out:
# NoneType

# %%
df.salary
# Out:
# 0      NaN
# 1       54
# 2       59
# 3      120
# 4       58
# 5       75
# 6     None
# 7      136
# 8       60
# 9      125
# 10     NaN
# Name: salary, dtype: object

# %%
type(df.salary[0])
# Out:
# float

# %%
type(df.salary[6])
# Out:
# NoneType

# %%
print(0 * np.nan)
print(np.nan == np.nan)
print(np.inf > np.nan)
print(np.nan - np.nan)
print(np.nan + np.nan)
print(np.nan - 10)
print(np.nan + 10)
print(np.nan in set([np.nan]))
print(0.3 == 3 * 0.1)
# Out:
# nan
# False
# False
# nan
# nan
# nan
# nan
# True
# False

# %%
np.nan is np.nan
# Out:
# True

# %%
df.status
# Out:
# 0      FT
# 1      PT
# 2       -
# 3      FT
# 4      PT
# 5      PT
# 6      FT
# 7       -
# 8      PT
# 9      FT
# 10    NaN
# Name: status, dtype: object

# %%
type(df.status[2])
# Out:
# str

# %%
type(df.status[1])
# Out:
# str

# %%
df.var1
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9       -
# 10      6
# Name: var1, dtype: object

# %%
display(df, df[["var1"]])
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN
#    var1
# 0     2
# 1     3
# 2     5
# 3   nan
# 4     7
# 5     1
# 6   nan
# 7    10
# 8    14
# 9     -
# 10    6

# %%
type(df.var1[3])
# Out:
# str

# %% [markdown]
# **What is the None keyword in Python? [ANSWER01](https://www.educative.io/edpresso/what-is-the-none-keyword-in-python), [ANSWER02](https://stackoverflow.com/questions/21095654/what-is-a-nonetype-object)**
#
# **Difference between None and NaN in Pandas [ANSWER01](https://www.skytowner.com/explore/difference_between_none_and_nan_in_pandas), [ANSWER02](https://kegui.medium.com/what-is-the-difference-between-nan-none-pd-nan-and-np-nan-a8ee0532e2eb)**
#
# **Difference between np.nan and np.NaN [ANSWER](https://stackoverflow.com/questions/53436339/difference-between-np-nan-and-np-nan)**
#
# **Difference between nan and 'nan' in Python [ANSWER01](https://stackoverflow.com/questions/40309789/difference-between-nan-and-nan-in-python), [ANSWER02](https://towardsdatascience.com/navigating-the-hell-of-nans-in-python-71b12558895b)**

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Detecting Missing Values</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# **``NaN``**, standing for "Not A Number", is a numeric data type used to represent any value that is undefined or unpresentable.
#
# For example, 0/0 is undefined as a real number and is, therefore, represented by NaN. The square root of a negative number is an imaginary number that cannot be represented as a real number, so, it is represented by NaN.
#
# **``NaN``** is also assigned to variables, in a computation, that do not have values and have yet to be computed.

# %%
df
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %%
display(df, df.isnull())  #df.isna() == df.isnull()
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN
#        id  gender  status   dept   var1   var2  salary
# 0   False   False   False  False  False  False    True
# 1   False   False   False  False  False   True   False
# 2   False   False   False  False  False  False   False
# 3   False   False   False  False  False  False   False
# 4   False   False   False  False  False  False   False
# 5   False   False   False   True  False   True   False
# 6   False   False   False  False  False   True    True
# 7   False   False   False  False  False  False   False
# 8   False   False   False   True  False  False   False
# 9   False   False   False  False  False  False   False
# 10  False   False    True  False  False  False    True

# %%
df.notnull()  #df.notnull() == df.notna()
# Out:
#       id  gender  status   dept  var1   var2  salary
# 0   True    True    True   True  True   True   False
# 1   True    True    True   True  True  False    True
# 2   True    True    True   True  True   True    True
# 3   True    True    True   True  True   True    True
# 4   True    True    True   True  True   True    True
# 5   True    True    True  False  True  False    True
# 6   True    True    True   True  True  False   False
# 7   True    True    True   True  True   True    True
# 8   True    True    True  False  True   True    True
# 9   True    True    True   True  True   True    True
# 10  True    True   False   True  True   True   False

# %%
df.isnull().any()
# Out:
# id        False
# gender    False
# status     True
# dept       True
# var1      False
# var2       True
# salary     True
# dtype: bool

# %%
df.isnull().any(axis=1)
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# dtype: bool

# %%
df.isna().sum()
# Out:
# id        0
# gender    0
# status    1
# dept      2
# var1      0
# var2      3
# salary    3
# dtype: int64

# %%
df.isna().sum().sum()  #tüm dataframe'de kaç tane null değer olduğunu söyler.
# Out:
# 9

# %%
df.salary.isnull()  #sadece bir Serie' ye de uygulanabilir.
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10     True
# Name: salary, dtype: bool

# %%
df.salary.isnull().any()  #bu sütunda null bir değer olduğu anlamına gelir.
# Out:
# True

# %%
df.salary.isnull().sum() #kaç tane null değer var?
# Out:
# 3

# %%
df.isnull().sum()/len(df) * 100  #Null değerlerin %lik değerlerini bulduk.
# Out:
# id         0.000000
# gender     0.000000
# status     9.090909
# dept      18.181818
# var1       0.000000
# var2      27.272727
# salary    27.272727
# dtype: float64

# %%
df[df.isnull().any(axis=1)]
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 8   P009      M     PT   NaN   14   3.0     60
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %%
df
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %%
df.loc[df.dept.isnull()]
# Out:
#      id gender status  dept var1  var2 salary
# 5  P006      F     PT  None    1   NaN     75
# 8  P009      M     PT   NaN   14   3.0     60

# %%
df.loc[df.dept.isnull(), "salary"]
# Out:
# 5    75
# 8    60
# Name: salary, dtype: object

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Converting Inappropriate Values to NaN Values</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# - map()
# - replace()

# %%
df["var1"].map({"-" : np.nan})   #element wise olmadığı için tüm seriyi nan yaptı.
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# Name: var1, dtype: float64

# %% [markdown]
# **Notes:** When **``arg``** parameter is a dictionary, values in Series that are NOT in the dictionary (as keys) are converted to NaN. However, if the dictionary is a dict subclass that defines __missing__ (i.e. provides a method for default values), then this default is used rather than NaN [SOURCE](https://www.w3resource.com/pandas/series/series-map.php#:~:text=The%20map()%20function%20is,a%20dict%20or%20a%20Series.&text=Mapping%20correspondence.&text=If%20'ignore'%2C%20propagate%20NaN,them%20to%20the%20mapping%20correspondence.).

# %%
df["var1"].replace(to_replace="-" ,value=np.nan)
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9     NaN
# 10      6
# Name: var1, dtype: object

# %%
df["var1"].replace(to_replace="-" ,value=np.nan).astype("float")
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df["var1"].replace(to_replace="-" ,value=np.nan).astype("float")
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df["var1"] = df["var1"].replace(to_replace="-", value=np.nan).astype("float")
df.var1
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df.status
# Out:
# 0      FT
# 1      PT
# 2       -
# 3      FT
# 4      PT
# 5      PT
# 6      FT
# 7       -
# 8      PT
# 9      FT
# 10    NaN
# Name: status, dtype: object

# %%
df["status"] = df["status"].replace("-", np.nan)  #eşitlediğimiz için değişiklik kalıcı oldu.
df.status
# Out:
# 0      FT
# 1      PT
# 2     NaN
# 3      FT
# 4      PT
# 5      PT
# 6      FT
# 7     NaN
# 8      PT
# 9      FT
# 10    NaN
# Name: status, dtype: object

# %%
df  # - 'lerden kurtulduk.
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
#df["gender"].map({"M":1, "F":0})
#df["gender"].replace({"M":1, "F":0})
df["gender"].replace(["M", "F"], [1, 0])  #hepsi aynı işlemi yaptı değişiklikler kalıcı olmadı.
# Out:
# 0     1
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     0
# 10    1
# Name: gender, dtype: int64

# %%
df.gender
# Out:
# 0     M
# 1     F
# 2     M
# 3     F
# 4     M
# 5     F
# 6     M
# 7     F
# 8     M
# 9     F
# 10    M
# Name: gender, dtype: object

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Missing Value Handling Methods</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
#  1. <b>Deleting (Dropping) Rows</b> ----->if it has more than 70-75% of missing values
#
#  2. <b>Replacing (Filling) With Mean/Median/Mode (Imputation)</b>--->can be applied on a feature which has numeric data
#
#  3. <b> Assigning An Unique Category</b>--->If a categorical feature has definite number of classes, we can assign another class
#
#  4. <b>Predicting The Missing Values</b>---> we can predict the nulls with the help of a machine learning algorithm like linear regression
#
#  5. <b>Using Algorithms Which Support Missing Values</b>--->KNN is a machine learning algorithm which works on the principle of distance measure.  This algorithm can be used when there are nulls present in the dataset.  KNN considers the missing values by taking the majority of the K nearest values

# %% [markdown]
#  ## 1 - Dropping
#
#  - dropna()
#  - drop()

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df.dropna(axis=0, how="any", thresh=None, inplace=False)  #içerdeki değerler default. Hiç nan olmayan satırları veriyor.
# Out:
#      id gender status dept  var1  var2 salary
# 4  P005      M     PT   DS   7.0  11.0     58

# %%
df.dropna(axis=1, how="any", thresh=None, inplace=False)  #hiç nan olmayan sütunları veriyor.
# Out:
#       id gender
# 0   P001      M
# 1   P002      F
# 2   P003      M
# 3   P004      F
# 4   P005      M
# 5   P006      F
# 6   P007      M
# 7   P008      F
# 8   P009      M
# 9   P010      F
# 10  P011      M

# %%
df.dropna(axis=1, how="all", thresh=None, inplace=False)  #tamamı nan olanları getir demek. tamamı nan olan olmadığı için değişiklik olmadı.
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# * **``any``** : If any NA values are present, drop that row or column.
# * **``all``** : If all values are NA, drop that row or column [Source](https://www.journaldev.com/33492/pandas-dropna-drop-null-na-values-from-dataframe).

# %%
df["delete_me"] = np.nan
df
# Out:
#       id gender status  dept  var1  var2 salary  delete_me
# 0   P001      M     FT    DS   2.0   8.0    NaN        NaN
# 1   P002      F     PT    FS   3.0   NaN     54        NaN
# 2   P003      M    NaN   AWS   5.0   5.0     59        NaN
# 3   P004      F     FT   AWS   NaN   8.0    120        NaN
# 4   P005      M     PT    DS   7.0  11.0     58        NaN
# 5   P006      F     PT  None   1.0   NaN     75        NaN
# 6   P007      M     FT    FS   NaN   NaN   None        NaN
# 7   P008      F    NaN    FS  10.0   2.0    136        NaN
# 8   P009      M     PT   NaN  14.0   3.0     60        NaN
# 9   P010      F     FT    DS   NaN   7.0    125        NaN
# 10  P011      M    NaN   AWS   6.0   9.0    NaN        NaN

# %%
df.dropna(axis=1, how="all", thresh=None, inplace=True)  #inplace true dediğimiz için kalıcı oalrak delete_me sütunu silindi.
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# **``thresh=N``** requires that a column has at least N **non-NaNs to survive.** [Source](https://stackoverflow.com/questions/51584906/thresh-in-dropna-for-dataframe-in-pandas-in-python/51584935)

# %%
df.dropna(axis=1, how="any", thresh=9, inplace=False)
# Out:
#       id gender  dept
# 0   P001      M    DS
# 1   P002      F    FS
# 2   P003      M   AWS
# 3   P004      F   AWS
# 4   P005      M    DS
# 5   P006      F  None
# 6   P007      M    FS
# 7   P008      F    FS
# 8   P009      M   NaN
# 9   P010      F    DS
# 10  P011      M   AWS

# %%
df.drop([1,3,5])
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 4   P005      M     PT   DS   7.0  11.0     58
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT  NaN  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %%
df.drop(["var1","var2"])  #axis belirtmezsek hata verir.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\federal\Desktop\Clarusway\DataScience\Python\DersKodları\DAwPy_S7_(Handling_with_Missing_Values)-student.ipynb Cell 64' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/federal/Desktop/Clarusway/DataScience/Python/DersKodlar%C4%B1/DAwPy_S7_%28Handling_with_Missing_Values%29-student.ipynb#ch0000063?line=0'>1</a> df.drop(["var1","var2"])
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:4948, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4799'>4800</a> @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4800'>4801</a> def drop(
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4801'>4802</a>     self,
#    (...)
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4808'>4809</a>     errors: str = "raise",
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4809'>4810</a> ):
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4810'>4811</a>     """
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4811'>4812</a>     Drop specified labels from rows or columns.
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4812'>4813</a>
#    (...)
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4945'>4946</a>             weight  1.0     0.8
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4946'>4947</a>     """
# -> <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4947'>4948</a>     return super().drop(
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4948'>4949</a>         labels=labels,
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4949'>4950</a>         axis=axis,
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4950'>4951</a>         index=index,
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4951'>4952</a>         columns=columns,
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4952'>4953</a>         level=level,
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4953'>4954</a>         inplace=inplace,
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4954'>4955</a>         errors=errors,
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4955'>4956</a>     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:4279, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/generic.py?line=4276'>4277</a> for axis, labels in axes.items():
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/generic.py?line=4277'>4278</a>     if labels is not None:
# -> <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/generic.py?line=4278'>4279</a>         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/generic.py?line=4280'>4281</a> if inplace:
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/generic.py?line=4281'>4282</a>     self._update_inplace(obj)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:4323, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/generic.py?line=4320'>4321</a>         new_axis = axis.drop(labels, level=level, errors=errors)
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/generic.py?line=4321'>4322</a>     else:
# -> <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/generic.py?line=4322'>4323</a>         new_axis = axis.drop(labels, errors=errors)
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/generic.py?line=4323'>4324</a>     indexer = axis.get_indexer(new_axis)
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/generic.py?line=4325'>4326</a> # Case for non-unique axis
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/generic.py?line=4326'>4327</a> else:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/indexes/base.py?line=6641'>6642</a> if mask.any():
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/indexes/base.py?line=6642'>6643</a>     if errors != "ignore":
# -> <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/indexes/base.py?line=6643'>6644</a>         raise KeyError(f"{list(labels[mask])} not found in axis")
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/indexes/base.py?line=6644'>6645</a>     indexer = indexer[~mask]
#    <a href='file:///c%3A/Users/federal/AppData/Roaming/Python/Python310/site-packages/pandas/core/indexes/base.py?line=6645'>6646</a> return self.delete(indexer)
#
# KeyError: "['var1', 'var2'] not found in axis"

# %%
df.drop(["var1","var2"],axis=1)
# Out:
#       id gender status  dept salary
# 0   P001      M     FT    DS    NaN
# 1   P002      F     PT    FS     54
# 2   P003      M    NaN   AWS     59
# 3   P004      F     FT   AWS    120
# 4   P005      M     PT    DS     58
# 5   P006      F     PT  None     75
# 6   P007      M     FT    FS   None
# 7   P008      F    NaN    FS    136
# 8   P009      M     PT   NaN     60
# 9   P010      F     FT    DS    125
# 10  P011      M    NaN   AWS    NaN

# %%
df.drop(columns=["var1","var2"])  #axis belirtmezsek de columns şeklinde yazmamız gerekir.
# Out:
#       id gender status  dept salary
# 0   P001      M     FT    DS    NaN
# 1   P002      F     PT    FS     54
# 2   P003      M    NaN   AWS     59
# 3   P004      F     FT   AWS    120
# 4   P005      M     PT    DS     58
# 5   P006      F     PT  None     75
# 6   P007      M     FT    FS   None
# 7   P008      F    NaN    FS    136
# 8   P009      M     PT   NaN     60
# 9   P010      F     FT    DS    125
# 10  P011      M    NaN   AWS    NaN

# %% [markdown]
#  ## 2 - Filling Missing Values (Imputation)

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
#  #### a.Filling with a specific value

# %%
df.fillna(0)  #tüm nan değerleri 0 ile doldurdu.
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0       0
# 1   P002      F     PT   FS   3.0   0.0      54
# 2   P003      M      0  AWS   5.0   5.0      59
# 3   P004      F     FT  AWS   0.0   8.0     120
# 4   P005      M     PT   DS   7.0  11.0      58
# 5   P006      F     PT    0   1.0   0.0      75
# 6   P007      M     FT   FS   0.0   0.0       0
# 7   P008      F      0   FS  10.0   2.0     136
# 8   P009      M     PT    0  14.0   3.0      60
# 9   P010      F     FT   DS   0.0   7.0     125
# 10  P011      M      0  AWS   6.0   9.0       0

# %%
df.var1.fillna(0)
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      0.0
# 4      7.0
# 5      1.0
# 6      0.0
# 7     10.0
# 8     14.0
# 9      0.0
# 10     6.0
# Name: var1, dtype: float64

# %% [markdown]
#  #### b.Filling with any Proper Value

# %%
df.var1.mean()
# Out:
# 6.0

# %%
df.var1.fillna(df.var1.mean())  #nan değerleri var1'in ortalamasıyla doldurdu.
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      6.0
# 4      7.0
# 5      1.0
# 6      6.0
# 7     10.0
# 8     14.0
# 9      6.0
# 10     6.0
# Name: var1, dtype: float64

# %%
df.mean()
# Out:
# C:\Users\federal\AppData\Local\Temp\ipykernel_11124\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# var1       6.000
# var2       6.625
# salary    85.875
# dtype: float64

# %%
df.fillna(df.mean())  # her sütundaki nan değerleri sütunun kendi ortalamasıyla doldurdu.
# Out:
# C:\Users\federal\AppData\Local\Temp\ipykernel_11124\3863540013.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean())  # her sütundaki nan değerleri sütunun kendi ortalamasıyla doldurdu.
#       id gender status  dept  var1    var2   salary
# 0   P001      M     FT    DS   2.0   8.000   85.875
# 1   P002      F     PT    FS   3.0   6.625   54.000
# 2   P003      M    NaN   AWS   5.0   5.000   59.000
# 3   P004      F     FT   AWS   6.0   8.000  120.000
# 4   P005      M     PT    DS   7.0  11.000   58.000
# 5   P006      F     PT  None   1.0   6.625   75.000
# 6   P007      M     FT    FS   6.0   6.625   85.875
# 7   P008      F    NaN    FS  10.0   2.000  136.000
# 8   P009      M     PT   NaN  14.0   3.000   60.000
# 9   P010      F     FT    DS   6.0   7.000  125.000
# 10  P011      M    NaN   AWS   6.0   9.000   85.875

# %%
df.fillna({"dept":"other", "var1":df.var1.mean(), "var2":df.var2.median()})
# Out:
#       id gender status   dept  var1  var2 salary
# 0   P001      M     FT     DS   2.0   8.0    NaN
# 1   P002      F     PT     FS   3.0   7.5     54
# 2   P003      M    NaN    AWS   5.0   5.0     59
# 3   P004      F     FT    AWS   6.0   8.0    120
# 4   P005      M     PT     DS   7.0  11.0     58
# 5   P006      F     PT  other   1.0   7.5     75
# 6   P007      M     FT     FS   6.0   7.5   None
# 7   P008      F    NaN     FS  10.0   2.0    136
# 8   P009      M     PT  other  14.0   3.0     60
# 9   P010      F     FT     DS   6.0   7.0    125
# 10  P011      M    NaN    AWS   6.0   9.0    NaN

# %% [markdown]
# **where() Replace values where the condition is False.**

# %%
df.notna()
# Out:
#       id  gender  status   dept   var1   var2  salary
# 0   True    True    True   True   True   True   False
# 1   True    True    True   True   True  False    True
# 2   True    True   False   True   True   True    True
# 3   True    True    True   True  False   True    True
# 4   True    True    True   True   True   True    True
# 5   True    True    True  False   True  False    True
# 6   True    True    True   True  False  False   False
# 7   True    True   False   True   True   True    True
# 8   True    True    True  False   True   True    True
# 9   True    True    True   True  False   True    True
# 10  True    True   False   True   True   True   False

# %%
#df.where(cond=df.notna(), other=df.mean(), axis=1)
df.where(cond = df.notna(), other=df.mean(), axis=1)
# Out:
# C:\Users\federal\AppData\Local\Temp\ipykernel_11124\748967018.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.where(cond = df.notna(), other=df.mean(), axis=1)
#       id gender status dept  var1    var2  salary
# 0   P001      M     FT   DS   2.0   8.000  85.875
# 1   P002      F     PT   FS   3.0   6.625      54
# 2   P003      M    NaN  AWS   5.0   5.000      59
# 3   P004      F     FT  AWS   6.0   8.000     120
# 4   P005      M     PT   DS   7.0  11.000      58
# 5   P006      F     PT  NaN   1.0   6.625      75
# 6   P007      M     FT   FS   6.0   6.625  85.875
# 7   P008      F    NaN   FS  10.0   2.000     136
# 8   P009      M     PT  NaN  14.0   3.000      60
# 9   P010      F     FT   DS   6.0   7.000     125
# 10  P011      M    NaN  AWS   6.0   9.000  85.875

# %% [markdown]
# **Fill NaN values using an interpolation method.**

# %%
df.interpolate()  #numeric değerlerin olduğu sütunlarda iki değerin arasındaki değeri eşit şekilde bölüyor.
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   6.5     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   6.0   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   8.0     75
# 6   P007      M     FT    FS   5.5   5.0   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS  10.0   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# For more information about [interpolation](https://www.geeksforgeeks.org/python-pandas-dataframe-interpolate/)

# %% [markdown]
#  #### c.Filling the Missing Values of Categorical Variables

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df.dept.mode()
# Out:
# 0    AWS
# 1     DS
# 2     FS
# Name: dept, dtype: object

# %%
df.dept.mode()[0]
# Out:
# 'AWS'

# %%
df.dept.fillna(df.dept.mode()[0])  #nan değerleri mode değeriyle doldurdu.
# Out:
# 0      DS
# 1      FS
# 2     AWS
# 3     AWS
# 4      DS
# 5     AWS
# 6      FS
# 7      FS
# 8     AWS
# 9      DS
# 10    AWS
# Name: dept, dtype: object

# %%
display(df.dept, df["dept"].fillna(method="ffill"))  #nan değerleri yukardan aşağı bakarak bir önceki değerle doldurur.
# Out:
# 0       DS
# 1       FS
# 2      AWS
# 3      AWS
# 4       DS
# 5     None
# 6       FS
# 7       FS
# 8      NaN
# 9       DS
# 10     AWS
# Name: dept, dtype: object
# 0      DS
# 1      FS
# 2     AWS
# 3     AWS
# 4      DS
# 5      DS
# 6      FS
# 7      FS
# 8      FS
# 9      DS
# 10    AWS
# Name: dept, dtype: object

# %%
display(df.dept, df["dept"].fillna(method="bfill"))  #nan değerleri aşağıdan yukarı bakarak bir önceki değerle doldurur.
# Out:
# 0       DS
# 1       FS
# 2      AWS
# 3      AWS
# 4       DS
# 5     None
# 6       FS
# 7       FS
# 8      NaN
# 9       DS
# 10     AWS
# Name: dept, dtype: object
# 0      DS
# 1      FS
# 2     AWS
# 3     AWS
# 4      DS
# 5      FS
# 6      FS
# 7      FS
# 8      DS
# 9      DS
# 10    AWS
# Name: dept, dtype: object

# %% [markdown]
# - **pad / ffill:** propagate last valid observation forward to next valid
# - **backfill / bfill:** use next valid observation to fill gap.

# %% [markdown]
#  #### d.Filling by condition & by Group of the Categorical Variables

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df.dept.fillna(method="ffill", inplace=True)
df
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %% [markdown]
# **Let's fill the missing values at "status" column with defined condition by "salary"**

# %%
df.loc[df["salary"] >= 100, "status"]
# Out:
# 3     FT
# 7    NaN
# 9     FT
# Name: status, dtype: object

# %%
df.loc[df["salary"] <= 100, "status"]
# Out:
# 1     PT
# 2    NaN
# 4     PT
# 5     PT
# 8     PT
# Name: status, dtype: object

# %%
df.loc[df["salary"]>=100, "status"].fillna(df.loc[df["salary"]>=100, "status"].mode()[0], inplace=True)
df.loc[df["salary"]<100, "status"].fillna(df.loc[df["salary"]<100, "status"].mode()[0], inplace=True)
df
# loc ile condition yaptığımızda inplace=True olursa çalışmıyor.
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %%
df.loc[df["salary"]>=100, "status"] = df.loc[df["salary"]>=100, "status"].fillna(df.loc[df["salary"]>=100, "status"].mode()[0])
df.loc[df["salary"]<100, "status"] = df.loc[df["salary"]<100, "status"].fillna(df.loc[df["salary"]<100, "status"].mode()[0])
df
# inplace=True yerine direk eşitliyoruz.
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M     PT  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F     FT   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %% [markdown]
# **Let's fill the last missing value at "status" column with the mode of the group of "gender" and "dept"**

# %%
df.groupby(["gender", "dept"])["status"].apply(lambda x: x.mode()[0])
# Out:
# gender  dept
# F       AWS     FT
#         DS      FT
#         FS      FT
# M       AWS     PT
#         DS      FT
#         FS      FT
# Name: status, dtype: object

# %%
df.groupby(["gender", "dept"])["status"].transform(lambda x : x.mode()[0])
# Out:
# 0     FT
# 1     FT
# 2     PT
# 3     FT
# 4     FT
# 5     FT
# 6     FT
# 7     FT
# 8     FT
# 9     FT
# 10    PT
# Name: status, dtype: object

# %%
df["trans_status"] = df.groupby(["gender", "dept"])["status"].transform(lambda x : x.mode()[0])
df
# Out:
#       id gender status dept  var1  var2 salary trans_status
# 0   P001      M     FT   DS   2.0   8.0    NaN           FT
# 1   P002      F     PT   FS   3.0   NaN     54           FT
# 2   P003      M     PT  AWS   5.0   5.0     59           PT
# 3   P004      F     FT  AWS   NaN   8.0    120           FT
# 4   P005      M     PT   DS   7.0  11.0     58           FT
# 5   P006      F     PT   DS   1.0   NaN     75           FT
# 6   P007      M     FT   FS   NaN   NaN   None           FT
# 7   P008      F     FT   FS  10.0   2.0    136           FT
# 8   P009      M     PT   FS  14.0   3.0     60           FT
# 9   P010      F     FT   DS   NaN   7.0    125           FT
# 10  P011      M    NaN  AWS   6.0   9.0    NaN           PT

# %%
df.status.fillna(df.trans_status, inplace=True)

# %%
df
# Out:
#       id gender status dept  var1  var2 salary trans_status
# 0   P001      M     FT   DS   2.0   8.0    NaN           FT
# 1   P002      F     PT   FS   3.0   NaN     54           FT
# 2   P003      M     PT  AWS   5.0   5.0     59           PT
# 3   P004      F     FT  AWS   NaN   8.0    120           FT
# 4   P005      M     PT   DS   7.0  11.0     58           FT
# 5   P006      F     PT   DS   1.0   NaN     75           FT
# 6   P007      M     FT   FS   NaN   NaN   None           FT
# 7   P008      F     FT   FS  10.0   2.0    136           FT
# 8   P009      M     PT   FS  14.0   3.0     60           FT
# 9   P010      F     FT   DS   NaN   7.0    125           FT
# 10  P011      M     PT  AWS   6.0   9.0    NaN           PT

# %% [markdown]
# **Let's fill the missing values at "salary" column with the mean of the group of "status" and "dept"**

# %%
df.groupby("dept").salary.mean()
# Out:
# dept
# AWS    89.500000
# DS     86.000000
# FS     83.333333
# Name: salary, dtype: float64

# %%
df.groupby(["status", "dept"]).salary.mean()
# Out:
# status  dept
# FT      AWS     120.0
#         DS      125.0
#         FS      136.0
# PT      AWS      59.0
#         DS       66.5
#         FS       57.0
# Name: salary, dtype: float64

# %%
df.groupby(["status", "dept"]).salary.transform("mean")
# Out:
# 0     125.0
# 1      57.0
# 2      59.0
# 3     120.0
# 4      66.5
# 5      66.5
# 6     136.0
# 7     136.0
# 8      57.0
# 9     125.0
# 10     59.0
# Name: salary, dtype: float64

# %%
df["trans_salary"] = df.groupby(["status", "dept"]).salary.transform("mean")
df
# Out:
#       id gender status dept  var1  var2 salary trans_status  trans_salary
# 0   P001      M     FT   DS   2.0   8.0    NaN           FT         125.0
# 1   P002      F     PT   FS   3.0   NaN     54           FT          57.0
# 2   P003      M     PT  AWS   5.0   5.0     59           PT          59.0
# 3   P004      F     FT  AWS   NaN   8.0    120           FT         120.0
# 4   P005      M     PT   DS   7.0  11.0     58           FT          66.5
# 5   P006      F     PT   DS   1.0   NaN     75           FT          66.5
# 6   P007      M     FT   FS   NaN   NaN   None           FT         136.0
# 7   P008      F     FT   FS  10.0   2.0    136           FT         136.0
# 8   P009      M     PT   FS  14.0   3.0     60           FT          57.0
# 9   P010      F     FT   DS   NaN   7.0    125           FT         125.0
# 10  P011      M     PT  AWS   6.0   9.0    NaN           PT          59.0

# %%
df.salary.fillna(df.trans_salary, inplace=True)
df
# Out:
#       id gender status dept  var1  var2  salary trans_status  trans_salary
# 0   P001      M     FT   DS   2.0   8.0   125.0           FT         125.0
# 1   P002      F     PT   FS   3.0   NaN    54.0           FT          57.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0           PT          59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0           FT         120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0           FT          66.5
# 5   P006      F     PT   DS   1.0   NaN    75.0           FT          66.5
# 6   P007      M     FT   FS   NaN   NaN   136.0           FT         136.0
# 7   P008      F     FT   FS  10.0   2.0   136.0           FT         136.0
# 8   P009      M     PT   FS  14.0   3.0    60.0           FT          57.0
# 9   P010      F     FT   DS   NaN   7.0   125.0           FT         125.0
# 10  P011      M     PT  AWS   6.0   9.0    59.0           PT          59.0

# %% [markdown]
# **Let's fill the missing values at "var1" column with the mean of the group of "gender" and "status"**

# %%
df.groupby(["gender", "status"]).var1.mean()
# Out:
# gender  status
# F       FT        10.0
#         PT         2.0
# M       FT         2.0
#         PT         8.0
# Name: var1, dtype: float64

# %%
trans_var1 = df.groupby(["gender", "status"]).var1.transform("mean")
trans_var1
# Out:
# 0      2.0
# 1      2.0
# 2      8.0
# 3     10.0
# 4      8.0
# 5      2.0
# 6      2.0
# 7     10.0
# 8      8.0
# 9     10.0
# 10     8.0
# Name: var1, dtype: float64

# %%
df.var1.fillna(trans_var1, inplace=True)
df
# Out:
#       id gender status dept  var1  var2  salary trans_status  trans_salary
# 0   P001      M     FT   DS   2.0   8.0   125.0           FT         125.0
# 1   P002      F     PT   FS   3.0   NaN    54.0           FT          57.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0           PT          59.0
# 3   P004      F     FT  AWS  10.0   8.0   120.0           FT         120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0           FT          66.5
# 5   P006      F     PT   DS   1.0   NaN    75.0           FT          66.5
# 6   P007      M     FT   FS   2.0   NaN   136.0           FT         136.0
# 7   P008      F     FT   FS  10.0   2.0   136.0           FT         136.0
# 8   P009      M     PT   FS  14.0   3.0    60.0           FT          57.0
# 9   P010      F     FT   DS  10.0   7.0   125.0           FT         125.0
# 10  P011      M     PT  AWS   6.0   9.0    59.0           PT          59.0

# %% [markdown]
# **Let's fill the missing values at "var2" column with the mean of group of "status"**

# %%
trans_var2 = df.groupby(["status", "dept"]).var2.transform("mean")
trans_var2
# Out:
# 0      7.5
# 1      3.0
# 2      7.0
# 3      8.0
# 4     11.0
# 5     11.0
# 6      2.0
# 7      2.0
# 8      3.0
# 9      7.5
# 10     7.0
# Name: var2, dtype: float64

# %%
df.var2.fillna(trans_var2, inplace=True)
df
# Out:
#       id gender status dept  var1  var2  salary trans_status  trans_salary
# 0   P001      M     FT   DS   2.0   8.0   125.0           FT         125.0
# 1   P002      F     PT   FS   3.0   3.0    54.0           FT          57.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0           PT          59.0
# 3   P004      F     FT  AWS  10.0   8.0   120.0           FT         120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0           FT          66.5
# 5   P006      F     PT   DS   1.0  11.0    75.0           FT          66.5
# 6   P007      M     FT   FS   2.0   2.0   136.0           FT         136.0
# 7   P008      F     FT   FS  10.0   2.0   136.0           FT         136.0
# 8   P009      M     PT   FS  14.0   3.0    60.0           FT          57.0
# 9   P010      F     FT   DS  10.0   7.0   125.0           FT         125.0
# 10  P011      M     PT  AWS   6.0   9.0    59.0           PT          59.0

# %% [markdown]
# ## filling with Interpolation
#
# Pandas **``dataframe.interpolate()``** function is basically used to fill NA values in the dataframe or series. But, this is a very powerful function to fill the missing values. It uses various interpolation technique to fill the missing values rather than hard-coding the value [Source 01](https://www.geeksforgeeks.org/python-pandas-dataframe-interpolate/) & [Source 02](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.interpolate.html)

# %%
flights = sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
flights.passengers.plot()
# Out:
# <AxesSubplot:>

# %%
flights_copy = flights.copy()

# %%
flights_copy.loc[np.random.randint(1,144,20), "passengers"] = np.nan

# %%
flights_copy.isnull().sum()
# Out:
# year           0
# month          0
# passengers    18
# dtype: int64

# %%
flights_copy.passengers.plot()
# Out:
# <AxesSubplot:>

# %%
display(flights_copy.passengers.interpolate().plot(), flights.passengers.plot());
# iki tablo arasındaki farkı görmek için.
# Out:
# <AxesSubplot:>
# <AxesSubplot:>

# %% [markdown]
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of The Session - 07</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ________
